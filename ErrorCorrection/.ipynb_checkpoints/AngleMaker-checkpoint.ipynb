# %%
import os
import sys
sys.path.append("../")
from NEAT.NEATUtils.MovieCreator import AngleAppender
from pathlib import Path

# %%
AngleCSV = '/home/sancere/Kepler/Lucas2Varun/1_Movies2_for_training_ONEAT/All_Movies/BIG1/BIG1_Divisions_Coordinates_TYXangle.csv'
ONTCSV = '/home/sancere/Kepler/Lucas2Varun/1_Movies2_for_training_ONEAT/All_Movies/BIG1/ONEATTimelapseBIG1BIG1_Divisions_Coordinates_TYXangle_kept.csv'
savedir = '/home/sancere/Kepler/FinalONEATTraining/NEATCSV/'
FirstColumn = 'Y'

# %%
 AngleAppender(AngleCSV, ONTCSV, savedir, ColumnA = FirstColumn)
