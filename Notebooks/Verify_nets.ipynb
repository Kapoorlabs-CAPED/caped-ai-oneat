# %%
from oneat.NEATModels import nets
model_keras = nets.resnet_lstm_v2
input_shape = (64,64,4)
Trainingmodel = model_keras(input_shape, 16, box_vector= 4,
                                              nboxes=1, stage_number=3,
                                               depth=29,
                                              start_kernel=3, mid_kernel = 3,
                                              startfilter=32, last_activation='relu',
                                              input_weights=None)
Trainingmodel.summary()
# Out:
# napari.manifest -> 'skeleton-finder' could not be imported: Cannot find module 'skeleton_finder' declared in entrypoint: 'skeleton_finder:napari.yaml'
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 4)]  0           []
#
#  conv_lstm1d (ConvLSTM1D)       (None, 64, 64, 32)   13952       ['input_1[0][0]']
#
#  conv2d (Conv2D)                (None, 64, 64, 32)   9248        ['conv_lstm1d[0][0]']
#
#  batch_normalization (BatchNorm  (None, 64, 64, 32)  128         ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 64, 64, 32)   0           ['batch_normalization[0][0]']
#
#  conv_lstm1d_1 (ConvLSTM1D)     (None, 64, 64, 32)   8320        ['activation[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 64, 64, 32)   1056        ['conv_lstm1d_1[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 64, 64, 32)  128         ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 64, 64, 32)   0           ['batch_normalization_1[0][0]']
#
#  conv_lstm1d_2 (ConvLSTM1D)     (None, 64, 64, 32)   24704       ['activation_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 32)   9248        ['conv_lstm1d_2[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 64, 64, 32)  128         ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 64, 64, 32)   0           ['batch_normalization_2[0][0]']
#
#  conv_lstm1d_4 (ConvLSTM1D)     (None, 64, 64, 128)  82432       ['activation[0][0]']
#
#  conv_lstm1d_3 (ConvLSTM1D)     (None, 64, 64, 128)  82432       ['activation_2[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 128)  16512       ['conv_lstm1d_4[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 128)  16512       ['conv_lstm1d_3[0][0]']
#
#  add (Add)                      (None, 64, 64, 128)  0           ['conv2d_4[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 64, 64, 128)  512        ['add[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 64, 64, 128)  0           ['batch_normalization_3[0][0]']
#
#  conv_lstm1d_5 (ConvLSTM1D)     (None, 64, 64, 32)   20608       ['activation_3[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 32)   1056        ['conv_lstm1d_5[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 64, 64, 32)  128         ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 64, 64, 32)   0           ['batch_normalization_4[0][0]']
#
#  conv_lstm1d_6 (ConvLSTM1D)     (None, 64, 64, 32)   24704       ['activation_4[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 32)   9248        ['conv_lstm1d_6[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 64, 64, 32)  128         ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 64, 64, 32)   0           ['batch_normalization_5[0][0]']
#
#  conv_lstm1d_7 (ConvLSTM1D)     (None, 64, 64, 128)  82432       ['activation_5[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 128)  16512       ['conv_lstm1d_7[0][0]']
#
#  add_1 (Add)                    (None, 64, 64, 128)  0           ['add[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 64, 64, 128)  512        ['add_1[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 64, 64, 128)  0           ['batch_normalization_6[0][0]']
#
#  conv_lstm1d_8 (ConvLSTM1D)     (None, 64, 64, 32)   20608       ['activation_6[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 64, 64, 32)   1056        ['conv_lstm1d_8[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 64, 64, 32)  128         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 64, 64, 32)   0           ['batch_normalization_7[0][0]']
#
#  conv_lstm1d_9 (ConvLSTM1D)     (None, 64, 64, 32)   24704       ['activation_7[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 64, 64, 32)   9248        ['conv_lstm1d_9[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 64, 64, 32)  128         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 64, 64, 32)   0           ['batch_normalization_8[0][0]']
#
#  conv_lstm1d_10 (ConvLSTM1D)    (None, 64, 64, 128)  82432       ['activation_8[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 64, 64, 128)  16512       ['conv_lstm1d_10[0][0]']
#
#  add_2 (Add)                    (None, 64, 64, 128)  0           ['add_1[0][0]',
#                                                                   'conv2d_10[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 64, 64, 128)  512        ['add_2[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 64, 64, 128)  0           ['batch_normalization_9[0][0]']
#
#  conv_lstm1d_11 (ConvLSTM1D)    (None, 64, 32, 128)  131584      ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 128)  16512       ['conv_lstm1d_11[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 32, 32, 128)  512        ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_10[0][0]']
#
#  conv_lstm1d_12 (ConvLSTM1D)    (None, 32, 32, 128)  393728      ['activation_10[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 128)  147584      ['conv_lstm1d_12[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 32, 32, 128)  512        ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_11[0][0]']
#
#  conv_lstm1d_14 (ConvLSTM1D)    (None, 64, 32, 256)  394240      ['add_2[0][0]']
#
#  conv_lstm1d_13 (ConvLSTM1D)    (None, 32, 32, 256)  394240      ['activation_11[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 32, 32, 256)  65792       ['conv_lstm1d_14[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 256)  65792       ['conv_lstm1d_13[0][0]']
#
#  add_3 (Add)                    (None, 32, 32, 256)  0           ['conv2d_14[0][0]',
#                                                                   'conv2d_13[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 32, 32, 256)  1024       ['add_3[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_12[0][0]']
#
#  conv_lstm1d_15 (ConvLSTM1D)    (None, 32, 32, 128)  197120      ['activation_12[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 32, 32, 128)  16512       ['conv_lstm1d_15[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 32, 32, 128)  512        ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_13[0][0]']
#
#  conv_lstm1d_16 (ConvLSTM1D)    (None, 32, 32, 128)  393728      ['activation_13[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 32, 32, 128)  147584      ['conv_lstm1d_16[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 32, 32, 128)  512        ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_14[0][0]']
#
#  conv_lstm1d_17 (ConvLSTM1D)    (None, 32, 32, 256)  394240      ['activation_14[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 32, 32, 256)  65792       ['conv_lstm1d_17[0][0]']
#
#  add_4 (Add)                    (None, 32, 32, 256)  0           ['add_3[0][0]',
#                                                                   'conv2d_17[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 32, 32, 256)  1024       ['add_4[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_15[0][0]']
#
#  conv_lstm1d_18 (ConvLSTM1D)    (None, 32, 32, 128)  197120      ['activation_15[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 32, 32, 128)  16512       ['conv_lstm1d_18[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 32, 32, 128)  512        ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_16[0][0]']
#
#  conv_lstm1d_19 (ConvLSTM1D)    (None, 32, 32, 128)  393728      ['activation_16[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 32, 32, 128)  147584      ['conv_lstm1d_19[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 32, 32, 128)  512        ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_17[0][0]']
#
#  conv_lstm1d_20 (ConvLSTM1D)    (None, 32, 32, 256)  394240      ['activation_17[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 32, 32, 256)  65792       ['conv_lstm1d_20[0][0]']
#
#  add_5 (Add)                    (None, 32, 32, 256)  0           ['add_4[0][0]',
#                                                                   'conv2d_20[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 32, 32, 256)  1024       ['add_5[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_18[0][0]']
#
#  conv_lstm1d_21 (ConvLSTM1D)    (None, 32, 16, 256)  525312      ['activation_18[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 16, 16, 256)  65792       ['conv_lstm1d_21[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_19[0][0]']
#
#  conv_lstm1d_22 (ConvLSTM1D)    (None, 16, 16, 256)  1573888     ['activation_19[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 16, 16, 256)  590080      ['conv_lstm1d_22[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_20[0][0]']
#
#  conv_lstm1d_24 (ConvLSTM1D)    (None, 32, 16, 512)  1574912     ['add_5[0][0]']
#
#  conv_lstm1d_23 (ConvLSTM1D)    (None, 16, 16, 512)  1574912     ['activation_20[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 16, 16, 512)  262656      ['conv_lstm1d_24[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 16, 16, 512)  262656      ['conv_lstm1d_23[0][0]']
#
#  add_6 (Add)                    (None, 16, 16, 512)  0           ['conv2d_24[0][0]',
#                                                                   'conv2d_23[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 16, 16, 512)  2048       ['add_6[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 16, 16, 512)  0           ['batch_normalization_21[0][0]']
#
#  conv_lstm1d_25 (ConvLSTM1D)    (None, 16, 16, 256)  787456      ['activation_21[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 16, 16, 256)  65792       ['conv_lstm1d_25[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_22[0][0]']
#
#  conv_lstm1d_26 (ConvLSTM1D)    (None, 16, 16, 256)  1573888     ['activation_22[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 16, 16, 256)  590080      ['conv_lstm1d_26[0][0]']
#  batch_normalization_23 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_23[0][0]']
#
#  conv_lstm1d_27 (ConvLSTM1D)    (None, 16, 16, 512)  1574912     ['activation_23[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 16, 16, 512)  262656      ['conv_lstm1d_27[0][0]']
#
#  add_7 (Add)                    (None, 16, 16, 512)  0           ['add_6[0][0]',
#                                                                   'conv2d_27[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 16, 16, 512)  2048       ['add_7[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 16, 16, 512)  0           ['batch_normalization_24[0][0]']
#
#  conv_lstm1d_28 (ConvLSTM1D)    (None, 16, 16, 256)  787456      ['activation_24[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 16, 16, 256)  65792       ['conv_lstm1d_28[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_25[0][0]']
#
#  conv_lstm1d_29 (ConvLSTM1D)    (None, 16, 16, 256)  1573888     ['activation_25[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 16, 16, 256)  590080      ['conv_lstm1d_29[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_26[0][0]']
#
#  conv_lstm1d_30 (ConvLSTM1D)    (None, 16, 16, 512)  1574912     ['activation_26[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 16, 16, 512)  262656      ['conv_lstm1d_30[0][0]']
#
#  add_8 (Add)                    (None, 16, 16, 512)  0           ['add_7[0][0]',
#                                                                   'conv2d_30[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 16, 16, 20)   92180       ['add_8[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 16, 16, 20)  80          ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 16, 16, 20)   0           ['batch_normalization_27[0][0]']
#
#  lambda (Lambda)                (None, 16, 16, 16)   0           ['activation_27[0][0]']
#
#  lambda_1 (Lambda)              (None, 16, 16, 4)    0           ['activation_27[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 1, 1, 16)     65552       ['lambda[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 1, 1, 4)      4100        ['lambda_1[0][0]']
#
#  Concat (Concat)                (None, 1, 1, 20)     0           ['conv2d_32[0][0]',
#                                                                   'conv2d_33[0][0]']
#
# ==================================================================================================
# Total params: 20,933,464
# Trainable params: 20,924,016
# Non-trainable params: 9,448
# __________________________________________________________________________________________________
