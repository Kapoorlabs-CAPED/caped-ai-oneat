# %%
from oneat.NEATModels import nets
model_keras = nets.resnet_lstm_v2
input_shape = (64,64,4)
Trainingmodel = model_keras(input_shape, 16, box_vector= 4,
                                              nboxes=1, stage_number=3,
                                               depth=29,
                                              start_kernel=3, mid_kernel = 3,
                                              startfilter=32, last_activation='relu',
                                              input_weights=None)
Trainingmodel.summary()
# Out:
# napari.manifest -> 'skeleton-finder' could not be imported: Cannot find module 'skeleton_finder' declared in entrypoint: 'skeleton_finder:napari.yaml'
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None, None,  0           []
#                                  4)]
#
#  conv_lstm1d (ConvLSTM1D)       (None, None, None,   13952       ['input_1[0][0]']
#                                 32)
#
#  conv2d (Conv2D)                (None, None, None,   33          ['conv_lstm1d[0][0]']
#                                 1)
#
#  batch_normalization (BatchNorm  (None, None, None,   4          ['conv2d[0][0]']
#  alization)                     1)
#
#  activation (Activation)        (None, None, None,   0           ['batch_normalization[0][0]']
#                                 1)
#
#  conv_lstm1d_1 (ConvLSTM1D)     (None, None, None,   4352        ['activation[0][0]']
#                                 32)
#
#  conv2d_1 (Conv2D)              (None, None, None,   33          ['conv_lstm1d_1[0][0]']
#                                 1)
#
#  batch_normalization_1 (BatchNo  (None, None, None,   4          ['conv2d_1[0][0]']
#  rmalization)                   1)
#
#  activation_1 (Activation)      (None, None, None,   0           ['batch_normalization_1[0][0]']
#                                 1)
#
#  conv_lstm1d_2 (ConvLSTM1D)     (None, None, None,   12800       ['activation_1[0][0]']
#                                 32)
#
#  conv2d_2 (Conv2D)              (None, None, None,   33          ['conv_lstm1d_2[0][0]']
#                                 1)
#
#  batch_normalization_2 (BatchNo  (None, None, None,   4          ['conv2d_2[0][0]']
#  rmalization)                   1)
#
#  activation_2 (Activation)      (None, None, None,   0           ['batch_normalization_2[0][0]']
#                                 1)
#
#  conv_lstm1d_4 (ConvLSTM1D)     (None, None, None,   66560       ['activation[0][0]']
#                                 128)
#
#  conv_lstm1d_3 (ConvLSTM1D)     (None, None, None,   66560       ['activation_2[0][0]']
#                                 128)
#
#  conv2d_4 (Conv2D)              (None, None, None,   129         ['conv_lstm1d_4[0][0]']
#                                 1)
#
#  conv2d_3 (Conv2D)              (None, None, None,   129         ['conv_lstm1d_3[0][0]']
#                                 1)
#
#  add (Add)                      (None, None, None,   0           ['conv2d_4[0][0]',
#                                 1)                                'conv2d_3[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, None, None,   4          ['add[0][0]']
#  rmalization)                   1)
#
#  activation_3 (Activation)      (None, None, None,   0           ['batch_normalization_3[0][0]']
#                                 1)
#
#  conv_lstm1d_5 (ConvLSTM1D)     (None, None, None,   4352        ['activation_3[0][0]']
#                                 32)
#
#  conv2d_5 (Conv2D)              (None, None, None,   33          ['conv_lstm1d_5[0][0]']
#                                 1)
#
#  batch_normalization_4 (BatchNo  (None, None, None,   4          ['conv2d_5[0][0]']
#  rmalization)                   1)
#
#  activation_4 (Activation)      (None, None, None,   0           ['batch_normalization_4[0][0]']
#                                 1)
#
#  conv_lstm1d_6 (ConvLSTM1D)     (None, None, None,   12800       ['activation_4[0][0]']
#                                 32)
#
#  conv2d_6 (Conv2D)              (None, None, None,   33          ['conv_lstm1d_6[0][0]']
#                                 1)
#
#  batch_normalization_5 (BatchNo  (None, None, None,   4          ['conv2d_6[0][0]']
#  rmalization)                   1)
#
#  activation_5 (Activation)      (None, None, None,   0           ['batch_normalization_5[0][0]']
#                                 1)
#
#  conv_lstm1d_7 (ConvLSTM1D)     (None, None, None,   66560       ['activation_5[0][0]']
#                                 128)
#
#  conv2d_7 (Conv2D)              (None, None, None,   129         ['conv_lstm1d_7[0][0]']
#                                 1)
#
#  add_1 (Add)                    (None, None, None,   0           ['add[0][0]',
#                                 1)                                'conv2d_7[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, None, None,   4          ['add_1[0][0]']
#  rmalization)                   1)
#
#  activation_6 (Activation)      (None, None, None,   0           ['batch_normalization_6[0][0]']
#                                 1)
#
#  conv_lstm1d_8 (ConvLSTM1D)     (None, None, None,   4352        ['activation_6[0][0]']
#                                 32)
#
#  conv2d_8 (Conv2D)              (None, None, None,   33          ['conv_lstm1d_8[0][0]']
#                                 1)
#
#  batch_normalization_7 (BatchNo  (None, None, None,   4          ['conv2d_8[0][0]']
#  rmalization)                   1)
#
#  activation_7 (Activation)      (None, None, None,   0           ['batch_normalization_7[0][0]']
#                                 1)
#
#  conv_lstm1d_9 (ConvLSTM1D)     (None, None, None,   12800       ['activation_7[0][0]']
#                                 32)
#
#  conv2d_9 (Conv2D)              (None, None, None,   33          ['conv_lstm1d_9[0][0]']
#                                 1)
#
#  batch_normalization_8 (BatchNo  (None, None, None,   4          ['conv2d_9[0][0]']
#  rmalization)                   1)
#
#  activation_8 (Activation)      (None, None, None,   0           ['batch_normalization_8[0][0]']
#                                 1)
#
#  conv_lstm1d_10 (ConvLSTM1D)    (None, None, None,   66560       ['activation_8[0][0]']
#                                 128)
#
#  conv2d_10 (Conv2D)             (None, None, None,   129         ['conv_lstm1d_10[0][0]']
#                                 1)
#
#  add_2 (Add)                    (None, None, None,   0           ['add_1[0][0]',
#                                 1)                                'conv2d_10[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, None, None,   4          ['add_2[0][0]']
#  rmalization)                   1)
#
#  activation_9 (Activation)      (None, None, None,   0           ['batch_normalization_9[0][0]']
#                                 1)
#
#  conv_lstm1d_11 (ConvLSTM1D)    (None, None, None,   66560       ['activation_9[0][0]']
#                                 128)
#
#  conv2d_11 (Conv2D)             (None, None, None,   129         ['conv_lstm1d_11[0][0]']
#                                 1)
#
#  batch_normalization_10 (BatchN  (None, None, None,   4          ['conv2d_11[0][0]']
#  ormalization)                  1)
#
#  activation_10 (Activation)     (None, None, None,   0           ['batch_normalization_10[0][0]']
#                                 1)
#
#  conv_lstm1d_12 (ConvLSTM1D)    (None, None, None,   198656      ['activation_10[0][0]']
#                                 128)
#
#  conv2d_12 (Conv2D)             (None, None, None,   129         ['conv_lstm1d_12[0][0]']
#                                 1)
#
#  batch_normalization_11 (BatchN  (None, None, None,   4          ['conv2d_12[0][0]']
#  ormalization)                  1)
#
#  activation_11 (Activation)     (None, None, None,   0           ['batch_normalization_11[0][0]']
#                                 1)
#
#  conv_lstm1d_14 (ConvLSTM1D)    (None, None, None,   264192      ['add_2[0][0]']
#                                 256)
#
#  conv_lstm1d_13 (ConvLSTM1D)    (None, None, None,   264192      ['activation_11[0][0]']
#                                 256)
#
#  conv2d_14 (Conv2D)             (None, None, None,   257         ['conv_lstm1d_14[0][0]']
#                                 1)
#
#  conv2d_13 (Conv2D)             (None, None, None,   257         ['conv_lstm1d_13[0][0]']
#                                 1)
#
#  add_3 (Add)                    (None, None, None,   0           ['conv2d_14[0][0]',
#                                 1)                                'conv2d_13[0][0]']
#
#  batch_normalization_12 (BatchN  (None, None, None,   4          ['add_3[0][0]']
#  ormalization)                  1)
#
#  activation_12 (Activation)     (None, None, None,   0           ['batch_normalization_12[0][0]']
#                                 1)
#
#  conv_lstm1d_15 (ConvLSTM1D)    (None, None, None,   66560       ['activation_12[0][0]']
#                                 128)
#
#  conv2d_15 (Conv2D)             (None, None, None,   129         ['conv_lstm1d_15[0][0]']
#                                 1)
#
#  batch_normalization_13 (BatchN  (None, None, None,   4          ['conv2d_15[0][0]']
#  ormalization)                  1)
#
#  activation_13 (Activation)     (None, None, None,   0           ['batch_normalization_13[0][0]']
#                                 1)
#
#  conv_lstm1d_16 (ConvLSTM1D)    (None, None, None,   198656      ['activation_13[0][0]']
#                                 128)
#
#  conv2d_16 (Conv2D)             (None, None, None,   129         ['conv_lstm1d_16[0][0]']
#                                 1)
#
#  batch_normalization_14 (BatchN  (None, None, None,   4          ['conv2d_16[0][0]']
#  ormalization)                  1)
#
#  activation_14 (Activation)     (None, None, None,   0           ['batch_normalization_14[0][0]']
#                                 1)
#
#  conv_lstm1d_17 (ConvLSTM1D)    (None, None, None,   264192      ['activation_14[0][0]']
#                                 256)
#
#  conv2d_17 (Conv2D)             (None, None, None,   257         ['conv_lstm1d_17[0][0]']
#                                 1)
#
#  add_4 (Add)                    (None, None, None,   0           ['add_3[0][0]',
#                                 1)                                'conv2d_17[0][0]']
#
#  batch_normalization_15 (BatchN  (None, None, None,   4          ['add_4[0][0]']
#  ormalization)                  1)
#
#  activation_15 (Activation)     (None, None, None,   0           ['batch_normalization_15[0][0]']
#                                 1)
#
#  conv_lstm1d_18 (ConvLSTM1D)    (None, None, None,   66560       ['activation_15[0][0]']
#                                 128)
#
#  conv2d_18 (Conv2D)             (None, None, None,   129         ['conv_lstm1d_18[0][0]']
#                                 1)
#
#  batch_normalization_16 (BatchN  (None, None, None,   4          ['conv2d_18[0][0]']
#  ormalization)                  1)
#
#  activation_16 (Activation)     (None, None, None,   0           ['batch_normalization_16[0][0]']
#                                 1)
#
#  conv_lstm1d_19 (ConvLSTM1D)    (None, None, None,   198656      ['activation_16[0][0]']
#                                 128)
#
#  conv2d_19 (Conv2D)             (None, None, None,   129         ['conv_lstm1d_19[0][0]']
#                                 1)
#
#  batch_normalization_17 (BatchN  (None, None, None,   4          ['conv2d_19[0][0]']
#  ormalization)                  1)
#
#  activation_17 (Activation)     (None, None, None,   0           ['batch_normalization_17[0][0]']
#                                 1)
#  conv_lstm1d_20 (ConvLSTM1D)    (None, None, None,   264192      ['activation_17[0][0]']
#                                 256)
#
#  conv2d_20 (Conv2D)             (None, None, None,   257         ['conv_lstm1d_20[0][0]']
#                                 1)
#
#  add_5 (Add)                    (None, None, None,   0           ['add_4[0][0]',
#                                 1)                                'conv2d_20[0][0]']
#
#  batch_normalization_18 (BatchN  (None, None, None,   4          ['add_5[0][0]']
#  ormalization)                  1)
#
#  activation_18 (Activation)     (None, None, None,   0           ['batch_normalization_18[0][0]']
#                                 1)
#
#  conv_lstm1d_21 (ConvLSTM1D)    (None, None, None,   264192      ['activation_18[0][0]']
#                                 256)
#
#  conv2d_21 (Conv2D)             (None, None, None,   257         ['conv_lstm1d_21[0][0]']
#                                 1)
#
#  batch_normalization_19 (BatchN  (None, None, None,   4          ['conv2d_21[0][0]']
#  ormalization)                  1)
#
#  activation_19 (Activation)     (None, None, None,   0           ['batch_normalization_19[0][0]']
#                                 1)
#
#  conv_lstm1d_22 (ConvLSTM1D)    (None, None, None,   790528      ['activation_19[0][0]']
#                                 256)
#
#  conv2d_22 (Conv2D)             (None, None, None,   257         ['conv_lstm1d_22[0][0]']
#                                 1)
#
#  batch_normalization_20 (BatchN  (None, None, None,   4          ['conv2d_22[0][0]']
#  ormalization)                  1)
#
#  activation_20 (Activation)     (None, None, None,   0           ['batch_normalization_20[0][0]']
#                                 1)
#
#  conv_lstm1d_24 (ConvLSTM1D)    (None, None, None,   1052672     ['add_5[0][0]']
#                                 512)
#
#  conv_lstm1d_23 (ConvLSTM1D)    (None, None, None,   1052672     ['activation_20[0][0]']
#                                 512)
#
#  conv2d_24 (Conv2D)             (None, None, None,   513         ['conv_lstm1d_24[0][0]']
#                                 1)
#
#  conv2d_23 (Conv2D)             (None, None, None,   513         ['conv_lstm1d_23[0][0]']
#                                 1)
#
#  add_6 (Add)                    (None, None, None,   0           ['conv2d_24[0][0]',
#                                 1)                                'conv2d_23[0][0]']
#
#  batch_normalization_21 (BatchN  (None, None, None,   4          ['add_6[0][0]']
#  ormalization)                  1)
#
#  activation_21 (Activation)     (None, None, None,   0           ['batch_normalization_21[0][0]']
#                                 1)
#
#  conv_lstm1d_25 (ConvLSTM1D)    (None, None, None,   264192      ['activation_21[0][0]']
#                                 256)
#
#  conv2d_25 (Conv2D)             (None, None, None,   257         ['conv_lstm1d_25[0][0]']
#                                 1)
#
#  batch_normalization_22 (BatchN  (None, None, None,   4          ['conv2d_25[0][0]']
#  ormalization)                  1)
#
#  activation_22 (Activation)     (None, None, None,   0           ['batch_normalization_22[0][0]']
#                                 1)
#
#  conv_lstm1d_26 (ConvLSTM1D)    (None, None, None,   790528      ['activation_22[0][0]']
#                                 256)
#
#  conv2d_26 (Conv2D)             (None, None, None,   257         ['conv_lstm1d_26[0][0]']
#                                 1)
#
#  batch_normalization_23 (BatchN  (None, None, None,   4          ['conv2d_26[0][0]']
#  ormalization)                  1)
#
#  activation_23 (Activation)     (None, None, None,   0           ['batch_normalization_23[0][0]']
#                                 1)
#
#  conv_lstm1d_27 (ConvLSTM1D)    (None, None, None,   1052672     ['activation_23[0][0]']
#                                 512)
#
#  conv2d_27 (Conv2D)             (None, None, None,   513         ['conv_lstm1d_27[0][0]']
#                                 1)
#
#  add_7 (Add)                    (None, None, None,   0           ['add_6[0][0]',
#                                 1)                                'conv2d_27[0][0]']
#
#  batch_normalization_24 (BatchN  (None, None, None,   4          ['add_7[0][0]']
#  ormalization)                  1)
#
#  activation_24 (Activation)     (None, None, None,   0           ['batch_normalization_24[0][0]']
#                                 1)
#
#  conv_lstm1d_28 (ConvLSTM1D)    (None, None, None,   264192      ['activation_24[0][0]']
#                                 256)
#
#  conv2d_28 (Conv2D)             (None, None, None,   257         ['conv_lstm1d_28[0][0]']
#                                 1)
#
#  batch_normalization_25 (BatchN  (None, None, None,   4          ['conv2d_28[0][0]']
#  ormalization)                  1)
#
#  activation_25 (Activation)     (None, None, None,   0           ['batch_normalization_25[0][0]']
#                                 1)
#
#  conv_lstm1d_29 (ConvLSTM1D)    (None, None, None,   790528      ['activation_25[0][0]']
#                                 256)
#
#  conv2d_29 (Conv2D)             (None, None, None,   257         ['conv_lstm1d_29[0][0]']
#                                 1)
#
#  batch_normalization_26 (BatchN  (None, None, None,   4          ['conv2d_29[0][0]']
#  ormalization)                  1)
#
#  activation_26 (Activation)     (None, None, None,   0           ['batch_normalization_26[0][0]']
#                                 1)
#
#  conv_lstm1d_30 (ConvLSTM1D)    (None, None, None,   1052672     ['activation_26[0][0]']
#                                 512)
#
#  conv2d_30 (Conv2D)             (None, None, None,   513         ['conv_lstm1d_30[0][0]']
#                                 1)
#
#  add_8 (Add)                    (None, None, None,   0           ['add_7[0][0]',
#                                 1)                                'conv2d_30[0][0]']
#
#  conv2d_31 (Conv2D)             (None, None, None,   200         ['add_8[0][0]']
#                                 20)
#
#  batch_normalization_27 (BatchN  (None, None, None,   80         ['conv2d_31[0][0]']
#  ormalization)                  20)
#
#  activation_27 (Activation)     (None, None, None,   0           ['batch_normalization_27[0][0]']
#                                 20)
#
#  lambda (Lambda)                (None, None, None,   0           ['activation_27[0][0]']
#                                 16)
#
#  lambda_1 (Lambda)              (None, None, None,   0           ['activation_27[0][0]']
#                                 4)
#
#  conv2d_32 (Conv2D)             (None, None, None,   65552       ['lambda[0][0]']
#                                 16)
#
#  conv2d_33 (Conv2D)             (None, None, None,   4100        ['lambda_1[0][0]']
#                                 4)
#
#  Concat (Concat)                (None, None, None,   0           ['conv2d_32[0][0]',
#                                 20)                               'conv2d_33[0][0]']
#
# ==================================================================================================
# Total params: 9,635,095
# Trainable params: 9,635,001
# Non-trainable params: 94
# __________________________________________________________________________________________________

# %%
model_keras = nets.resnet_v2
input_shape = (64,64,4)
Trainingmodel = model_keras(input_shape, 16, box_vector= 4,
                                              nboxes=1, stage_number=3,
                                               depth=29,
                                              start_kernel=3, mid_kernel = 3,
                                              startfilter=32, last_activation='relu',
                                              input_weights=None)
Trainingmodel.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, None, None,  0           []
#                                  4)]
#
#  conv2d_34 (Conv2D)             (None, None, None,   1184        ['input_2[0][0]']
#                                 32)
#
#  batch_normalization_28 (BatchN  (None, None, None,   128        ['conv2d_34[0][0]']
#  ormalization)                  32)
#
#  activation_28 (Activation)     (None, None, None,   0           ['batch_normalization_28[0][0]']
#                                 32)
#
#  conv2d_35 (Conv2D)             (None, None, None,   1056        ['activation_28[0][0]']
#                                 32)
#
#  batch_normalization_29 (BatchN  (None, None, None,   128        ['conv2d_35[0][0]']
#  ormalization)                  32)
#
#  activation_29 (Activation)     (None, None, None,   0           ['batch_normalization_29[0][0]']
#                                 32)
#
#  conv2d_36 (Conv2D)             (None, None, None,   9248        ['activation_29[0][0]']
#                                 32)
#
#  batch_normalization_30 (BatchN  (None, None, None,   128        ['conv2d_36[0][0]']
#  ormalization)                  32)
#
#  activation_30 (Activation)     (None, None, None,   0           ['batch_normalization_30[0][0]']
#                                 32)
#
#  conv2d_38 (Conv2D)             (None, None, None,   4224        ['activation_28[0][0]']
#                                 128)
#
#  conv2d_37 (Conv2D)             (None, None, None,   4224        ['activation_30[0][0]']
#                                 128)
#
#  add_9 (Add)                    (None, None, None,   0           ['conv2d_38[0][0]',
#                                 128)                              'conv2d_37[0][0]']
#
#  batch_normalization_31 (BatchN  (None, None, None,   512        ['add_9[0][0]']
#  ormalization)                  128)
#
#  activation_31 (Activation)     (None, None, None,   0           ['batch_normalization_31[0][0]']
#                                 128)
#
#  conv2d_39 (Conv2D)             (None, None, None,   4128        ['activation_31[0][0]']
#                                 32)
#
#  batch_normalization_32 (BatchN  (None, None, None,   128        ['conv2d_39[0][0]']
#  ormalization)                  32)
#
#  activation_32 (Activation)     (None, None, None,   0           ['batch_normalization_32[0][0]']
#                                 32)
#
#  conv2d_40 (Conv2D)             (None, None, None,   9248        ['activation_32[0][0]']
#                                 32)
#
#  batch_normalization_33 (BatchN  (None, None, None,   128        ['conv2d_40[0][0]']
#  ormalization)                  32)
#
#  activation_33 (Activation)     (None, None, None,   0           ['batch_normalization_33[0][0]']
#                                 32)
#
#  conv2d_41 (Conv2D)             (None, None, None,   4224        ['activation_33[0][0]']
#                                 128)
#
#  add_10 (Add)                   (None, None, None,   0           ['add_9[0][0]',
#                                 128)                              'conv2d_41[0][0]']
#
#  batch_normalization_34 (BatchN  (None, None, None,   512        ['add_10[0][0]']
#  ormalization)                  128)
#
#  activation_34 (Activation)     (None, None, None,   0           ['batch_normalization_34[0][0]']
#                                 128)
#
#  conv2d_42 (Conv2D)             (None, None, None,   4128        ['activation_34[0][0]']
#                                 32)
#
#  batch_normalization_35 (BatchN  (None, None, None,   128        ['conv2d_42[0][0]']
#  ormalization)                  32)
#
#  activation_35 (Activation)     (None, None, None,   0           ['batch_normalization_35[0][0]']
#                                 32)
#
#  conv2d_43 (Conv2D)             (None, None, None,   9248        ['activation_35[0][0]']
#                                 32)
#
#  batch_normalization_36 (BatchN  (None, None, None,   128        ['conv2d_43[0][0]']
#  ormalization)                  32)
#
#  activation_36 (Activation)     (None, None, None,   0           ['batch_normalization_36[0][0]']
#                                 32)
#
#  conv2d_44 (Conv2D)             (None, None, None,   4224        ['activation_36[0][0]']
#                                 128)
#
#  add_11 (Add)                   (None, None, None,   0           ['add_10[0][0]',
#                                 128)                              'conv2d_44[0][0]']
#
#  batch_normalization_37 (BatchN  (None, None, None,   512        ['add_11[0][0]']
#  ormalization)                  128)
#
#  activation_37 (Activation)     (None, None, None,   0           ['batch_normalization_37[0][0]']
#                                 128)
#
#  conv2d_45 (Conv2D)             (None, None, None,   16512       ['activation_37[0][0]']
#                                 128)
#
#  batch_normalization_38 (BatchN  (None, None, None,   512        ['conv2d_45[0][0]']
#  ormalization)                  128)
#
#  activation_38 (Activation)     (None, None, None,   0           ['batch_normalization_38[0][0]']
#                                 128)
#
#  conv2d_46 (Conv2D)             (None, None, None,   147584      ['activation_38[0][0]']
#                                 128)
#
#  batch_normalization_39 (BatchN  (None, None, None,   512        ['conv2d_46[0][0]']
#  ormalization)                  128)
#
#  activation_39 (Activation)     (None, None, None,   0           ['batch_normalization_39[0][0]']
#                                 128)
#
#  conv2d_48 (Conv2D)             (None, None, None,   33024       ['add_11[0][0]']
#                                 256)
#
#  conv2d_47 (Conv2D)             (None, None, None,   33024       ['activation_39[0][0]']
#                                 256)
#
#  add_12 (Add)                   (None, None, None,   0           ['conv2d_48[0][0]',
#                                 256)                              'conv2d_47[0][0]']
#
#  batch_normalization_40 (BatchN  (None, None, None,   1024       ['add_12[0][0]']
#  ormalization)                  256)
#
#  activation_40 (Activation)     (None, None, None,   0           ['batch_normalization_40[0][0]']
#                                 256)
#
#  conv2d_49 (Conv2D)             (None, None, None,   32896       ['activation_40[0][0]']
#                                 128)
#
#  batch_normalization_41 (BatchN  (None, None, None,   512        ['conv2d_49[0][0]']
#  ormalization)                  128)
#
#  activation_41 (Activation)     (None, None, None,   0           ['batch_normalization_41[0][0]']
#                                 128)
#
#  conv2d_50 (Conv2D)             (None, None, None,   147584      ['activation_41[0][0]']
#                                 128)
#
#  batch_normalization_42 (BatchN  (None, None, None,   512        ['conv2d_50[0][0]']
#  ormalization)                  128)
#
#  activation_42 (Activation)     (None, None, None,   0           ['batch_normalization_42[0][0]']
#                                 128)
#
#  conv2d_51 (Conv2D)             (None, None, None,   33024       ['activation_42[0][0]']
#                                 256)
#
#  add_13 (Add)                   (None, None, None,   0           ['add_12[0][0]',
#                                 256)                              'conv2d_51[0][0]']
#
#  batch_normalization_43 (BatchN  (None, None, None,   1024       ['add_13[0][0]']
#  ormalization)                  256)
#
#  activation_43 (Activation)     (None, None, None,   0           ['batch_normalization_43[0][0]']
#                                 256)
#
#  conv2d_52 (Conv2D)             (None, None, None,   32896       ['activation_43[0][0]']
#                                 128)
#
#  batch_normalization_44 (BatchN  (None, None, None,   512        ['conv2d_52[0][0]']
#  ormalization)                  128)
#
#  activation_44 (Activation)     (None, None, None,   0           ['batch_normalization_44[0][0]']
#                                 128)
#
#  conv2d_53 (Conv2D)             (None, None, None,   147584      ['activation_44[0][0]']
#                                 128)
#
#  batch_normalization_45 (BatchN  (None, None, None,   512        ['conv2d_53[0][0]']
#  ormalization)                  128)
#
#  activation_45 (Activation)     (None, None, None,   0           ['batch_normalization_45[0][0]']
#                                 128)
#
#  conv2d_54 (Conv2D)             (None, None, None,   33024       ['activation_45[0][0]']
#                                 256)
#
#  add_14 (Add)                   (None, None, None,   0           ['add_13[0][0]',
#                                 256)                              'conv2d_54[0][0]']
#
#  batch_normalization_46 (BatchN  (None, None, None,   1024       ['add_14[0][0]']
#  ormalization)                  256)
#
#  activation_46 (Activation)     (None, None, None,   0           ['batch_normalization_46[0][0]']
#                                 256)
#
#  conv2d_55 (Conv2D)             (None, None, None,   65792       ['activation_46[0][0]']
#                                 256)
#
#  batch_normalization_47 (BatchN  (None, None, None,   1024       ['conv2d_55[0][0]']
#  ormalization)                  256)
#
#  activation_47 (Activation)     (None, None, None,   0           ['batch_normalization_47[0][0]']
#                                 256)
#
#  conv2d_56 (Conv2D)             (None, None, None,   590080      ['activation_47[0][0]']
#                                 256)
#
#  batch_normalization_48 (BatchN  (None, None, None,   1024       ['conv2d_56[0][0]']
#  ormalization)                  256)
#
#  activation_48 (Activation)     (None, None, None,   0           ['batch_normalization_48[0][0]']
#                                 256)
#
#  conv2d_58 (Conv2D)             (None, None, None,   131584      ['add_14[0][0]']
#                                 512)
#
#  conv2d_57 (Conv2D)             (None, None, None,   131584      ['activation_48[0][0]']
#                                 512)
#
#  add_15 (Add)                   (None, None, None,   0           ['conv2d_58[0][0]',
#                                 512)                              'conv2d_57[0][0]']
#
#  batch_normalization_49 (BatchN  (None, None, None,   2048       ['add_15[0][0]']
#  ormalization)                  512)
#
#  activation_49 (Activation)     (None, None, None,   0           ['batch_normalization_49[0][0]']
#                                 512)
#
#  conv2d_59 (Conv2D)             (None, None, None,   131328      ['activation_49[0][0]']
#                                 256)
#
#  batch_normalization_50 (BatchN  (None, None, None,   1024       ['conv2d_59[0][0]']
#  ormalization)                  256)
#
#  activation_50 (Activation)     (None, None, None,   0           ['batch_normalization_50[0][0]']
#                                 256)
#
#  conv2d_60 (Conv2D)             (None, None, None,   590080      ['activation_50[0][0]']
#                                 256)
#
#  batch_normalization_51 (BatchN  (None, None, None,   1024       ['conv2d_60[0][0]']
#  ormalization)                  256)
#  activation_51 (Activation)     (None, None, None,   0           ['batch_normalization_51[0][0]']
#                                 256)
#
#  conv2d_61 (Conv2D)             (None, None, None,   131584      ['activation_51[0][0]']
#                                 512)
#
#  add_16 (Add)                   (None, None, None,   0           ['add_15[0][0]',
#                                 512)                              'conv2d_61[0][0]']
#
#  batch_normalization_52 (BatchN  (None, None, None,   2048       ['add_16[0][0]']
#  ormalization)                  512)
#
#  activation_52 (Activation)     (None, None, None,   0           ['batch_normalization_52[0][0]']
#                                 512)
#
#  conv2d_62 (Conv2D)             (None, None, None,   131328      ['activation_52[0][0]']
#                                 256)
#
#  batch_normalization_53 (BatchN  (None, None, None,   1024       ['conv2d_62[0][0]']
#  ormalization)                  256)
#
#  activation_53 (Activation)     (None, None, None,   0           ['batch_normalization_53[0][0]']
#                                 256)
#
#  conv2d_63 (Conv2D)             (None, None, None,   590080      ['activation_53[0][0]']
#                                 256)
#
#  batch_normalization_54 (BatchN  (None, None, None,   1024       ['conv2d_63[0][0]']
#  ormalization)                  256)
#
#  activation_54 (Activation)     (None, None, None,   0           ['batch_normalization_54[0][0]']
#                                 256)
#
#  conv2d_64 (Conv2D)             (None, None, None,   131584      ['activation_54[0][0]']
#                                 512)
#
#  add_17 (Add)                   (None, None, None,   0           ['add_16[0][0]',
#                                 512)                              'conv2d_64[0][0]']
#
#  conv2d_65 (Conv2D)             (None, None, None,   92180       ['add_17[0][0]']
#                                 20)
#
#  batch_normalization_55 (BatchN  (None, None, None,   80         ['conv2d_65[0][0]']
#  ormalization)                  20)
#
#  activation_55 (Activation)     (None, None, None,   0           ['batch_normalization_55[0][0]']
#                                 20)
#
#  lambda_2 (Lambda)              (None, None, None,   0           ['activation_55[0][0]']
#                                 16)
#
#  lambda_3 (Lambda)              (None, None, None,   0           ['activation_55[0][0]']
#                                 4)
#
#  conv2d_66 (Conv2D)             (None, None, None,   65552       ['lambda_2[0][0]']
#                                 16)
#
#  conv2d_67 (Conv2D)             (None, None, None,   4100        ['lambda_3[0][0]']
#                                 4)
#
#  Concat (Concat)                (None, None, None,   0           ['conv2d_66[0][0]',
#                                 20)                               'conv2d_67[0][0]']
#
# ==================================================================================================
# Total params: 3,518,040
# Trainable params: 3,508,592
# Non-trainable params: 9,448
# __________________________________________________________________________________________________
