# %%
import sys
import os
import glob
from oneat.NEATModels import NEATSynamic
from oneat.NEATModels.config import dynamic_config
from oneat.NEATUtils import helpers
from oneat.NEATUtils.helpers import load_json
os.environ["CUDA_VISIBLE_DEVICES"]="0"
os.environ["HDF5_USE_FILE_LOCKING"] = "FALSE"
from pathlib import Path

# %%
imagedir = 'D:/TestDatasets/Oneat/Hela_brightfield/'
model_dir = 'D:/TrainingModels/Oneat/'
savedir= 'D:/TestDatasets/Oneat/Hela_brightfield/results_d29f32s3k3/'
model_name = 'Cellsplitdetectorbrightfieldd29f32s3k3'

division_categories_json = model_dir + 'Cellsplithelafloucategories.json'
catconfig = load_json(division_categories_json)
division_cord_json = model_dir + 'Cellsplithelafloucord.json'
cordconfig = load_json(division_cord_json)
model = NEATSynamic(None, model_dir , model_name,catconfig, cordconfig)
Path(savedir).mkdir(exist_ok=True)
n_tiles = (4,4)
event_threshold = 1 - 1.0E-4
iou_threshold = 0.3
fidelity = 4
downsamplefactor = 1
Raw_path = os.path.join(imagedir, '*tif')
X = glob.glob(Raw_path)

for imagename in X:

     model.predict_synamic(imagename,
                           savedir, 
                           n_tiles = n_tiles, 
                           event_threshold = event_threshold, 
                           iou_threshold = iou_threshold,
                           fidelity = fidelity,
                           downsamplefactor = downsamplefactor )
# Out:
# Detecting event locations
#   0%|▎                                                                               | 1/240 [00:18<1:12:21, 18.16s/it]
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# 0.750375596442806
# -2
# -2
# -2
# 0.7629928463025136
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# 0.7532881837680356
# -2
# -2
# -2
# -2
# -2
# -2
# 0.8696500713110922
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# 0.7616833322275659
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# 0.8726409808015128
# 0.7497072213942574
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# 0.8771597106557898
# -2
# -2
# -2
# -2
# 0.8720462659000376
# 0.8352602818182091
# 0.8553565304903166
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# 0.8695038445256325
# -2
# -2
# -2
# 0.7436676156759929
# -2
# 0.86520386272512
# -2
# -2
# -2
# -2
# 0.818811337018489
# -2
# -2
# -2
# -2
# 0.7471329141551619
# -2
# 0.7502700135296266
# -2
# -2
# -2
# 0.6815626742131107
# -2
# -2
# -2
# -2
# 0.4472442512952481
# 0.5040768660897224
# -2
# -2
# -2
# -2
# 0.6107472291691673
# 0.7571439243437277
# -2
# -2
# -2
# -2
# 0.6361948968758698
# -2
# -2
# -2
# 0.7411298669407832
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# 0.5389172476170735
# 0.8679451840876274
# -2
# -2
# -2
# -2
# 0.7881830640668189
# 0.8762656459619886
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# 0.9444150584552596
# 0.6790440767932229
# -2
# -2
# -2
# -2
# -2
# 0.740043417288843
# -2
# -2
# -2
# -2
# -2
# 0.8784441840600029
# 0.7690825739267674
# -2
# -2
# -2
#   1%|▋                                                                                 | 2/240 [00:23<41:23, 10.43s/it]
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# 0.8173400532215184
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# 0.8759830121009423
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# 0.8429917774881803
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# 0.9235484459452417
# 0.8157817624761923
# -2
# 0.8531541181595331
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# 0.7472146073181067
# 0.7727264231062985
# 0.7697759371444131
# 0.678269776833172
# -2
# -2
# -2
# -2
# 0.7006084408699212
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# 0.7636969517556847
# 0.5375425957035739
# -2
# -2
# -2
# -2
# 0.5924916905512718
# 0.8658112467050392
# -2
# -2
# -2
# -2
# 0.6750653887914976
# -2
# 0.9071256153122
# -2
# -2
# -2
# -2
# -2
# 0.7273571944996249
# -2
# -2
# 0.4017708599456611
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# 0.6082265817729602
# 0.8560238935617441
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# 0.883032768751049
# 0.8781257308376408
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# 0.8796385815893643
# -2
# 0.6018049305879729
# -2
# -2
# 0.7144823990656632
# -2
# 0.7738760853008636
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# 0.8585329014766991
# -2
# -2
# -2
# -2
# -2
# 0.7687591853114901
# 0.6956159829936616
# -2
# -2
# -2
# -2
# -2
# 0.8163243927486701
# -2
# 0.8569470504594462
# -2
# -2
# -2
# -2
# -2
#   1%|█                                                                                 | 3/240 [00:28<31:23,  7.95s/it]
# -2
# -2
# -2
# 0.6182340082736879
# -2
# -2
# 0.8615315554787851
# -2
# 0.7384124331295264
# -2
# -2
# -2
# -2
# -2
# 0.8333537915885585
# -2
# -2
# -2
# -2
# 0.7176862040565176
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# 0
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# 0.7963023194027172
# -2
# -2
# 0.8772280909773982
# -2
# 0.8666628403306254
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# 0.7828607328747834
# 0.883802400277142
# -2
# -2
# -2
# -2
# -2
# 0.8745785166627321
# -2
# -2
#   2%|██                                                                                | 6/240 [00:43<22:27,  5.76s/it]
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# 0.1553732447670258
# -2
# -2
# -2
# -2
# 0.8820833600992134
# -2
# 0.8705963903343064
# -2
# 0.8396314365033819
# -2
# -2
# 0.8193777097380658
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# 0.9362496184442834
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# 0.8281279467658952
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# 0.852836377157674
# 0.6574132147487735
# -2
# 0.6166145371740731
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# 0.8736886839427954
# -2
# -2
# -2
# -2
# -2
# 0.8632568561279044
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# 0.5574730772379808
# 0.6399161167249456
# -2
# 0.7349471519317615
# 0.7203453669182432
# -2
# 0.8957476437452642
# 0.6069098472922517
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# 0.8587244470594817
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# 0.5414756794449213
# 0.4927620150145825
# -2
# 0.7143492188199441
# -2
# -2
# 0.5987268812498415
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# 0.9002743405223486
# -2
# -2
# -2
# -2
# -2
# -2
# 0.8311201393910419
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# -2
# 0.8341247677507904
# -2
# -2
# -2
# -2
# -2
# 0.6217715089569587
# 0.6783257824312428
# -2
# -2
# -2
# 0.6492572858246717
# 0.5706730618862139
# -2
# -2
# -2
# 0.6640544726525517
# 0.6884065113126123
# -2
# -2
# -2
# 0.690071587982588
# 0.6109125120852302
# -2
# -2
# -2
# 0.6920205147485377
# -2
# 0.8675018930319169
#   2%|██                                                                                | 6/240 [00:45<29:20,  7.52s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4440/2829096543.py in <module>
#      20 for imagename in X:
#      21
# ---> 22      model.predict_synamic(imagename,
#      23                            savedir,
#      24                            n_tiles = n_tiles,
#
# c:\users\rando\downloads\caped-ai-oneat\oneat\NEATModels\neat_faststandard.py in predict_synamic(self, imagename, savedir, n_tiles, overlap_percent, event_threshold, iou_threshold, fidelity, downsamplefactor, maskimage, maskfilter)
#      19      downsamplefactor = 1, maskimage = None, maskfilter = 10):
#      20
# ---> 21         self.predict(imagename,savedir,n_tiles = n_tiles, overlap_percent = overlap_percent, event_threshold = event_threshold, iou_threshold = iou_threshold,
#      22         fidelity = fidelity, downsamplefactor = downsamplefactor, maskimage = maskimage, maskfilter = maskfilter,  markers = None, marker_tree = None,
#      23          remove_markers = None )
#
# c:\users\rando\downloads\caped-ai-oneat\oneat\NEATModels\neat_goldstandard.py in predict(self, imagename, savedir, n_tiles, overlap_percent, event_threshold, iou_threshold, fidelity, downsamplefactor, maskfilter, markers, marker_tree, watershed, maskimage, remove_markers)
#     372            self.second_pass_predict()
#     373         if self.remove_markers == None:
# --> 374            self.default_pass_predict()
#     375
#     376     def default_pass_predict(self):
#
# c:\users\rando\downloads\caped-ai-oneat\oneat\NEATModels\neat_goldstandard.py in default_pass_predict(self)
#     396                                 # Cut off the region for training movie creation
#     397                                 #Break image into tiles if neccessary
# --> 398                                 predictions, allx, ally = self.predict_main(smallimage)
#     399                                 #Iterate over tiles
#     400                                 for p in range(0,len(predictions)):
#
# c:\users\rando\downloads\caped-ai-oneat\oneat\NEATModels\neat_goldstandard.py in predict_main(self, sliceregion)
#     850             if len(self.patch) > 0:
#     851                 for i in range(0, len(self.patch)):
# --> 852                     sum_time_prediction = self.make_patches(self.patch[i])
#     853                     predictions.append(sum_time_prediction)
#     854                     allx.append(self.sx[i])
#
# c:\users\rando\downloads\caped-ai-oneat\oneat\NEATModels\neat_goldstandard.py in make_patches(self, sliceregion)
#     879         predict_im = np.expand_dims(sliceregion, 0)
#     880
# --> 881         prediction_vector = self.model.predict(np.expand_dims(predict_im, -1), verbose=0)
#     882
#     883         return prediction_vector
#
# ~\anaconda3\envs\naparienv\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\envs\naparienv\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2010       self._distribution_strategy = original_pss_strategy
#    2011
# -> 2012     return tf_utils.sync_to_numpy_or_python_type(all_outputs)
#    2013
#    2014   def reset_metrics(self):
#
# ~\anaconda3\envs\naparienv\lib\site-packages\keras\utils\tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     561     return t.item() if np.ndim(t) == 0 else t
#     562
# --> 563   return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     564
#     565
#
# ~\anaconda3\envs\naparienv\lib\site-packages\tensorflow\python\util\nest.py in map_structure(func, *structure, **kwargs)
#     912
#     913   return pack_sequence_as(
# --> 914       structure[0], [func(*x) for x in entries],
#     915       expand_composites=expand_composites)
#     916
#
# ~\anaconda3\envs\naparienv\lib\site-packages\tensorflow\python\util\nest.py in <listcomp>(.0)
#     912
#     913   return pack_sequence_as(
# --> 914       structure[0], [func(*x) for x in entries],
#     915       expand_composites=expand_composites)
#     916
#
# ~\anaconda3\envs\naparienv\lib\site-packages\keras\utils\tf_utils.py in _to_single_numpy_or_python_type(t)
#     555     # Don't turn ragged or sparse tensors to NumPy.
#     556     if isinstance(t, tf.Tensor):
# --> 557       t = t.numpy()
#     558     # Strings, ragged and sparse tensors don't have .item(). Return them as-is.
#     559     if not isinstance(t, (np.ndarray, np.generic)):
#
# ~\anaconda3\envs\naparienv\lib\site-packages\tensorflow\python\framework\ops.py in numpy(self)
#    1221     """
#    1222     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1223     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1224     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1225
#
# ~\anaconda3\envs\naparienv\lib\site-packages\tensorflow\python\framework\ops.py in _numpy(self)
#    1187   def _numpy(self):
#    1188     try:
# -> 1189       return self._numpy_internal()
#    1190     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1191       raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
imagedir = 'D:/TestDatasets/Oneat/Hela_brightfield/'
model_dir = 'D:/TrainingModels/Oneat/'
savedir= 'D:/TestDatasets/Oneat/Hela_brightfield/results_d29f32s4k3/'
model_name = 'Cellsplitdetectorbrightfieldd29f32s4k3'

division_categories_json = model_dir + 'Cellsplithelafloucategories.json'
catconfig = load_json(division_categories_json)
division_cord_json = model_dir + 'Cellsplithelafloucord.json'
cordconfig = load_json(division_cord_json)
model = NEATSynamic(None, model_dir , model_name,catconfig, cordconfig)
Path(savedir).mkdir(exist_ok=True)

Raw_path = os.path.join(imagedir, '*tif')
X = glob.glob(Raw_path)

for imagename in X:

     model.predict_synamic(imagename,
                           savedir, 
                           n_tiles = n_tiles, 
                           event_threshold = event_threshold, 
                           iou_threshold = iou_threshold,
                           fidelity = fidelity,
                           downsamplefactor = downsamplefactor )

# %%
imagedir = 'D:/TestDatasets/Oneat/Hela_brightfield/'
model_dir = 'D:/TrainingModels/Oneat/'
savedir= 'D:/TestDatasets/Oneat/Hela_brightfield/results_d29f32s3k5/'
model_name = 'Cellsplitdetectorbrightfieldd29f32s3k5'

division_categories_json = model_dir + 'Cellsplithelafloucategories.json'
catconfig = load_json(division_categories_json)
division_cord_json = model_dir + 'Cellsplithelafloucord.json'
cordconfig = load_json(division_cord_json)
model = NEATSynamic(None, model_dir , model_name,catconfig, cordconfig)
Path(savedir).mkdir(exist_ok=True)

Raw_path = os.path.join(imagedir, '*tif')
X = glob.glob(Raw_path)

for imagename in X:

     model.predict_synamic(imagename,
                           savedir, 
                           n_tiles = n_tiles, 
                           event_threshold = event_threshold, 
                           iou_threshold = iou_threshold,
                           fidelity = fidelity,
                           downsamplefactor = downsamplefactor )

# %%
imagedir = 'D:/TestDatasets/Oneat/Hela_flou/'
model_dir = 'D:/TrainingModels/Oneat/'
savedir= 'D:/TestDatasets/Oneat/Hela_flou/results_d29f32s3/'
model_name = 'Cellsplitdetectorfloud29f32s3'

division_categories_json = model_dir + 'Cellsplithelafloucategories.json'
catconfig = load_json(division_categories_json)
division_cord_json = model_dir + 'Cellsplithelafloucord.json'
cordconfig = load_json(division_cord_json)
model = NEATSynamic(None, model_dir , model_name,catconfig, cordconfig)
Path(savedir).mkdir(exist_ok=True)

Raw_path = os.path.join(imagedir, '*tif')
X = glob.glob(Raw_path)

for imagename in X:

     model.predict_synamic(imagename,
                           savedir, 
                           n_tiles = n_tiles, 
                           event_threshold = event_threshold, 
                           iou_threshold = iou_threshold,
                           fidelity = fidelity,
                           downsamplefactor = downsamplefactor )

# %%
imagedir = 'D:/TestDatasets/Oneat/Hela_flou/'
model_dir = 'D:/TrainingModels/Oneat/'
savedir= 'D:/TestDatasets/Oneat/Hela_flou/results_d29f32s4/'
model_name = 'Cellsplitdetectorfloud29f32s4'

division_categories_json = model_dir + 'Cellsplithelafloucategories.json'
catconfig = load_json(division_categories_json)
division_cord_json = model_dir + 'Cellsplithelafloucord.json'
cordconfig = load_json(division_cord_json)
model = NEATSynamic(None, model_dir , model_name,catconfig, cordconfig)
Path(savedir).mkdir(exist_ok=True)

Raw_path = os.path.join(imagedir, '*tif')
X = glob.glob(Raw_path)

for imagename in X:

     model.predict_synamic(imagename,
                           savedir, 
                           n_tiles = n_tiles, 
                           event_threshold = event_threshold, 
                           iou_threshold = iou_threshold,
                           fidelity = fidelity,
                           downsamplefactor = downsamplefactor )
