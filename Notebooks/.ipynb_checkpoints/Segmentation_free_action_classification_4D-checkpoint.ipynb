# %%
import sys
import os
import glob
from csbdeep.models import  CARE
from oneat.NEATModels import NEATSynamic
from oneat.NEATModels.config import dynamic_config
from oneat.NEATUtils import helpers
from oneat.NEATUtils.helpers import load_json
os.environ["CUDA_VISIBLE_DEVICES"]="0"
os.environ["HDF5_USE_FILE_LOCKING"] = "FALSE"
from pathlib import Path

# %%
n_tiles = (8,8)
event_threshold = 0.9
event_confidence = 0.9
iou_threshold = 0.4
fidelity = 4
downsamplefactor = 1
#For a Z of 0 to 22 this setup takes the slices from 11 - 4 = 7 to 11 + 1 = 12
start_project_mid = 4
end_project_mid = 1
normalize = True

# %%
imagedir = 'D:/TestDatasets/Oneat/Xenopus_oneat/'
model_dir = 'D:/TrainingModels/Oneat/'
savedir= 'D:/TestDatasets/Oneat/Xenopus_oneat/results_d29f8_fid4_iou0.4/'
model_name = 'Cellsplitsxenopus_xy64_tm1tp1_s3d29f8'


division_categories_json = model_dir + 'Cellsplitcategoriesxenopus.json'
catconfig = load_json(division_categories_json)
division_cord_json = model_dir + 'Cellsplitcordxenopus.json'
cordconfig = load_json(division_cord_json)
model = NEATSynamic(None, model_dir , model_name,catconfig, cordconfig)

Path(savedir).mkdir(exist_ok=True)

Raw_path = os.path.join(imagedir, '*tif')
X = glob.glob(Raw_path)
 
for imagename in X:

     model.predict_synamic(imagename,
                           savedir, 
                           n_tiles = n_tiles, 
                           event_threshold = event_threshold, 
                           event_confidence = event_confidence,
                           iou_threshold = iou_threshold,
                           fidelity = fidelity,
                           downsamplefactor = downsamplefactor,
                           start_project_mid = start_project_mid,
                           end_project_mid = end_project_mid,
                           normalize = normalize)
# Out:
# Loading network weights from 'weights_best.h5'.
# Image (41, 22, 1112, 1112) is 4 dimensional, projecting around the center 11 - 4 to 11 + 1
# Detecting event locations
#   5%|████                                                                               | 2/41 [00:21<06:43, 10.36s/it]
# [{'Normal': 6.190671e-07, 'Division': 0.9999994, 'xstart': 266, 'ystart': 631, 'tstart': 1.0, 'xcenterraw': 0.4755493104457855, 'ycenterraw': 0.50916588306427, 'tcenterraw': 0.49569880962371826, 'xcenter': 296.4351558685303, 'ycenter': 663.5866165161133, 'real_time_event': 2.0, 'box_time_event': 0.0, 'height': 27.261398315429688, 'width': 23.22566032409668, 'confidence': 0.9801874756813049, 'realangle': 2, 'rawangle': 2}, {'Normal': 6.879031e-07, 'Division': 0.9999993, 'xstart': 397, 'ystart': 222, 'tstart': 0.0, 'xcenterraw': 0.5091372132301331, 'ycenterraw': 0.5018520355224609, 'tcenterraw': 0.4965432584285736, 'xcenter': 429.5847816467285, 'ycenter': 254.1185302734375, 'real_time_event': 1.0, 'box_time_event': 0.0, 'height': 25.633804321289062, 'width': 29.78046226501465, 'confidence': 0.9103581309318542, 'realangle': 2, 'rawangle': 2}, {'Normal': 8.619506e-06, 'Division': 0.9999914, 'xstart': 444, 'ystart': 365, 'tstart': 0.0, 'xcenterraw': 0.47411084175109863, 'ycenterraw': 0.5080285668373108, 'tcenterraw': 0.5065091848373413, 'xcenter': 474.3430938720703, 'ycenter': 397.5138282775879, 'real_time_event': 1.0, 'box_time_event': 0.0, 'height': 31.077594757080078, 'width': 27.911705017089844, 'confidence': 0.9069793820381165, 'realangle': 
 'realangle': 2, 'rawangle': 2}, {'Normal': 0.0013744484, 'Division': 0.9986255, 'xstart': 853, 'ystart': 1023, 'tstart': 13.0, 'xcenterraw': 0.500400185585022, 'ycenterraw': 0.5072933435440063, 'tcenterraw': 0.48599010705947876, 'xcenter': 885.0256118774414, 'ycenter': 1055.4667739868164, 'real_time_event': 14.0, 'box_time_event': 0.0, 'height': 26.183683395385742, 'width': 30.853628158569336, 'confidence': 0.9224109649658203, 'realangle': 2, 'rawangle': 2}, {'Normal': 0.0014029125, 'Division': 0.9985971, 'xstart': 956, 'ystart': 516, 'tstart': 13.0, 'xcenterraw': 0.48846814036369324, 'ycenterraw': 0.5021052956581116, 'tcenterraw': 0.4796009361743927, 'xcenter': 987.2619609832764, 'ycenter': 548.1347389221191, 'real_time_event': 14.0, 'box_time_event': 0.0, 'height': 26.669824600219727, 'width': 21.315614700317383, 'confidence': 0.9061175584793091, 'realangle': 2, 'rawangle': 2}, {'Normal': 0.0018689068, 'Division': 0.9981311, 'xstart': 76, 'ystart': 674, 'tstart': 13.0, 'xcenterraw': 0.49179360270500183, 'ycenterraw': 0.5027612447738647, 'tcenterraw': 0.5046924352645874, 'xcenter': 107.47479057312012, 'ycenter': 706.1767196655273, 'real_time_event': 14.0, 'box_time_event': 0.0, 'height': 36.296112060546875, 'width': 37.60253143310547, 'confidence': 0.9181060194969177, 'realangle': 2, 'rawangle': 2}, {'Normal': 0.0050290534, 'Division': 0.9949709, 'xstart': 286, 'ystart': 742, 'tstart': 13.0, 'xcenterraw': 0.47906607389450073, 'ycenterraw': 0.5070054531097412, 'tcenterraw': 0.49347835779190063, 'xcenter': 316.66022872924805, 'ycenter': 774.4483489990234, 'real_time_event': 14.0, 'box_time_event': 0.0, 'height': 22.524581909179688, 'width': 26.166181564331055, 'confidence': 0.9636468887329102, 'realangle': 2, 'rawangle': 2}, {'Normal': 0.022050282, 'Division': 0.9779497, 'xstart': 853, 'ystart': 1011, 'tstart': 13.0, 'xcenterraw': 0.51094651222229, 'ycenterraw': 0.516120195388794, 'tcenterraw': 0.5001086592674255, 'xcenter': 885.7005767822266, 'ycenter': 1044.0316925048828, 'real_time_event': 14.0, 'box_time_event': 0.0, 'height': 19.874540328979492, 'width': 19.813316345214844, 'confidence': 0.9311330318450928, 'realangle': 2, 'rawangle': 2}]
#  34%|████████████████████████████                                                      | 14/41 [02:11<04:14,  9.41s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14860/307482884.py in <module>
#      24 for imagename in X:
#      25
# ---> 26      model.predict_synamic(imagename,
#      27                            savedir,
#      28                            n_tiles = n_tiles,
#
# c:\users\rando\downloads\caped-ai-oneat\oneat\NEATModels\neat_faststandard.py in predict_synamic(self, imagename, savedir, n_tiles, overlap_percent, event_threshold, event_confidence, iou_threshold, fidelity, downsamplefactor, erosion_iterations, start_project_mid, end_project_mid, maskmodel, maskdir, normalize)
#      19      downsamplefactor = 1, erosion_iterations = 10,start_project_mid = 4, end_project_mid = 4, maskmodel = None, maskdir = None, normalize = True):
#      20
# ---> 21         self.predict(imagename,savedir,n_tiles = n_tiles, overlap_percent = overlap_percent, event_threshold = event_threshold, event_confidence = event_confidence, iou_threshold = iou_threshold,
#      22         fidelity = fidelity, start_project_mid = start_project_mid, end_project_mid = end_project_mid, downsamplefactor = downsamplefactor, erosion_iterations = erosion_iterations,  markers = None, marker_tree = None,
#      23          remove_markers = None, maskmodel = maskmodel, maskdir = maskdir, normalize = normalize )
#
# c:\users\rando\downloads\caped-ai-oneat\oneat\NEATModels\neat_goldstandard.py in predict(self, imagename, savedir, n_tiles, overlap_percent, event_threshold, event_confidence, iou_threshold, fidelity, downsamplefactor, start_project_mid, end_project_mid, erosion_iterations, markers, marker_tree, watershed, remove_markers, maskmodel, maskdir, normalize)
#     400            self.second_pass_predict()
#     401         if self.remove_markers == None:
# --> 402            self.default_pass_predict()
#     403
#     404     def default_pass_predict(self):
#
# c:\users\rando\downloads\caped-ai-oneat\oneat\NEATModels\neat_goldstandard.py in default_pass_predict(self)
#     424                                 # Cut off the region for training movie creation
#     425                                 #Break image into tiles if neccessary
# --> 426                                 predictions, allx, ally = self.predict_main(smallimage)
#     427                                 #Iterate over tiles
#     428                                 for p in range(0,len(predictions)):
#
# c:\users\rando\downloads\caped-ai-oneat\oneat\NEATModels\neat_goldstandard.py in predict_main(self, sliceregion)
#     882             if len(self.patch) > 0:
#     883                 for i in range(0, len(self.patch)):
# --> 884                     sum_time_prediction = self.make_patches(self.patch[i])
#     885                     predictions.append(sum_time_prediction)
#     886                     allx.append(self.sx[i])
#
# c:\users\rando\downloads\caped-ai-oneat\oneat\NEATModels\neat_goldstandard.py in make_patches(self, sliceregion)
#     911         predict_im = np.expand_dims(sliceregion, 0)
#     912
# --> 913         prediction_vector = self.model.predict(np.expand_dims(predict_im, -1), verbose=0)
#     914
#     915         return prediction_vector
#
# ~\anaconda3\envs\naparienv\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\envs\naparienv\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1949               stacklevel=2)
#    1950
# -> 1951       data_handler = data_adapter.get_data_handler(
#    1952           x=x,
#    1953           batch_size=batch_size,
#
# ~\anaconda3\envs\naparienv\lib\site-packages\keras\engine\data_adapter.py in get_data_handler(*args, **kwargs)
#    1397   if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1398     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1399   return DataHandler(*args, **kwargs)
#    1400
#    1401
#
# ~\anaconda3\envs\naparienv\lib\site-packages\keras\engine\data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1147
#    1148     adapter_cls = select_data_adapter(x, y)
# -> 1149     self._adapter = adapter_cls(
#    1150         x,
#    1151         y,
#
# ~\anaconda3\envs\naparienv\lib\site-packages\keras\engine\data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     326     indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     327
# --> 328     dataset = self.slice_inputs(indices_dataset, inputs)
#     329
#     330     if shuffle == "batch":
#
# ~\anaconda3\envs\naparienv\lib\site-packages\keras\engine\data_adapter.py in slice_inputs(self, indices_dataset, inputs)
#     350       A Dataset of input batches matching the batch indices.
#     351     """
# --> 352     dataset = tf.data.Dataset.zip((
#     353         indices_dataset,
#     354         tf.data.Dataset.from_tensors(inputs).repeat()
#
# ~\anaconda3\envs\naparienv\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in zip(datasets, name)
#    1226       Dataset: A `Dataset`.
#    1227     """
# -> 1228     return ZipDataset(datasets, name=name)
#    1229
#    1230   def concatenate(self, dataset, name=None):
#
# ~\anaconda3\envs\naparienv\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in __init__(self, datasets, name)
#    4627     if name:
#    4628       self._metadata.name = _validate_and_encode(name)
# -> 4629     variant_tensor = gen_dataset_ops.zip_dataset(
#    4630         [ds._variant_tensor for ds in nest.flatten(self._datasets)],
#    4631         **self._common_args)
#
# ~\anaconda3\envs\naparienv\lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py in zip_dataset(input_datasets, output_types, output_shapes, metadata, name)
#    8040   if tld.is_eager:
#    8041     try:
# -> 8042       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    8043         _ctx, "ZipDataset", name, input_datasets, "output_types",
#    8044         output_types, "output_shapes", output_shapes, "metadata", metadata)
#
# KeyboardInterrupt:
